# %% [markdown]
# Volume

# %%
import pandas as pd
#generate a large volume of random data(eg. 1 millon data points)
volume_data = pd.read_csv('/content/drive/MyDrive/DAP_TEAM 4/datasets/insurance_dataset.csv')
print("volume of data:",len(volume_data))
# Out:
# volume of data: 7

# %% [markdown]
# Velocity

# %%
import time
import numpy as np
#simulate streaming data every second for 10 seconds
velocity_data = pd.read_csv('/content/drive/MyDrive/DAP_TEAM 4/datasets/insurance_dataset.csv')
for i in range(10):
  velocity_data=np.random.rand( )#generate random data
  print("velocity data point:",velocity_data)
  time.sleep(2)#wait for 1 second to simulate real-time data stream
# Out:
# velocity data point: 0.196812617451812
# velocity data point: 0.4039332702587015
# velocity data point: 0.532896065158615
# velocity data point: 0.6077000211944779
# velocity data point: 0.5911193489099671
# velocity data point: 0.7763988426366317
# velocity data point: 0.22563869688743088
# velocity data point: 0.35219217728086694
# velocity data point: 0.5502670445066062
# velocity data point: 0.9163366365186316

# %% [markdown]
# Veracity

# %%
import pandas as pd
import random
#generate some random data with noise
veracity_data = pd.read_csv('/content/drive/MyDrive/DAP_TEAM 4/datasets/insurance_dataset.csv')
veracity_data=[random.choice([1,2,3,None])for _ in range(20)]
print("veracity data:",veracity_data)
# Out:
# veracity data: [2, 3, 2, 2, 3, 2, 2, 2, 1, 3, 3, 1, 2, 3, 1, 1, 1, 3, 3, 2]

# %% [markdown]
# Variety

# %%
print("Variety of data:")
print(volume_data.info())
# Out:
# Variety of data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Age      7 non-null      int64
#  1   Premium  7 non-null      int64
# dtypes: int64(2)
# memory usage: 240.0 bytes
# None

# %%
structured_data = pd.read_csv('/content/drive/MyDrive/DAP_TEAM 4/datasets/insurance_dataset.csv', sep =',')
#structured data
print(structured_data)
#semi-structured data(JSON)
semistructured_data = pd.read_csv('/content/drive/MyDrive/DAP_TEAM 4/datasets/insurance_dataset.csv', sep =',')
print(semistructured_data)
#unstructured data(text)
unstructured_data="This is a sample text document.It can contain any information in free form"
print(unstructured_data)
# Out:
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000
#    Age  Premium
# 0   18    10000
# 1   22    15000
# 2   23    18000
# 3   26    21000
# 4   28    24000
# 5   31    26500
# 6   33    27000
# This is a sample text document.It can contain any information in free form
