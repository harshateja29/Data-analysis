# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv('/content/demoDT.csv',sep=",")
print(df)
# Out:
#    State  Literacy   Cleanliness   Crime_Rate  good
# 0      A        92            90           54     0
# 1      B        56            67           50     1
# 2      C        78            80           62     1
# 3      D        85            75           48     0
# 4      E        60            82           55     0
# 5      F        72            78           60     1
# 6      G        88            85           45     1
# 7      H        64            70           58     1
# 8      I        90            88           42     1
# 9      J        68            72           65     0
# 10     K        75            79           57     1
# 11     L        82            86           49     0
# 12     M        58            65           63     0
# 13     N        77            76           52     0
# 14     O        94            91           40     0
# 15     P        63            74           61     1
# 16     Q        79            83           47     1
# 17     R        71            68           59     1
# 18     S        86            89           43     1
# 19     T        66            71           64     1
# 20     U        81            81           51     1
# 21     V        70            77           56     1
# 22     W        87            84           46     0
# 23     X        62            69           66     1
# 24     Y        76            73           53     0
# 25     Z        83            87           44     1

# %%
feature_cols = ['Literacy',' Cleanliness',' Crime_Rate']
feature = df[feature_cols] #Features
Target = df.good #Target variable

# %%
RF = RandomForestClassifier(n_estimators=100)
RF.fit(feature,Target)
# Out:
# RandomForestClassifier()

# %%
l = int(input("Enter Literacy: "))
cl = int(input("Enter Cleanliness: "))
cr = int(input("Enter CrimeRate: "))
pred = RF.predict([[l,cl,cr]])
if pred==1:
  print("Good State")
else:
    print("Bad State")
# Out:
# Enter Literacy: 92
# Enter Cleanliness: 90
# Enter CrimeRate: 54
# Bad State
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import os
output_dir = "tree_visualizations"
os.makedirs(output_dir,exist_ok=True)

# %%
RF.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1860991290),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1919115831),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1785811811),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1671489158),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1061098664),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1298686398),
#  DecisionTreeClassifier(max_features='sqrt', random_state=221850664),
#  DecisionTreeClassifier(max_features='sqrt', random_state=58105622),
#  DecisionTreeClassifier(max_features='sqrt', random_state=183308157),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2004226647),
#  DecisionTreeClassifier(max_features='sqrt', random_state=26147707),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1077284505),
#  DecisionTreeClassifier(max_features='sqrt', random_state=803852465),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1806815921),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1771263085),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1903291968),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1494568109),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1382270012),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1598529030),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2122112683),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1578969955),
#  DecisionTreeClassifier(max_features='sqrt', random_state=304337916),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1470036529),
#  DecisionTreeClassifier(max_features='sqrt', random_state=85210811),
#  DecisionTreeClassifier(max_features='sqrt', random_state=81136548),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1293430499),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2101010636),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1397505605),
#  DecisionTreeClassifier(max_features='sqrt', random_state=979642101),
#  DecisionTreeClassifier(max_features='sqrt', random_state=386502235),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1209923437),
#  DecisionTreeClassifier(max_features='sqrt', random_state=912139267),
#  DecisionTreeClassifier(max_features='sqrt', random_state=459406870),
#  DecisionTreeClassifier(max_features='sqrt', random_state=458701958),
#  DecisionTreeClassifier(max_features='sqrt', random_state=494442818),
#  DecisionTreeClassifier(max_features='sqrt', random_state=254430184),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1499302621),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1050602387),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1050789426),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2063194850),
#  DecisionTreeClassifier(max_features='sqrt', random_state=617944456),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1156536633),
#  DecisionTreeClassifier(max_features='sqrt', random_state=88407404),
#  DecisionTreeClassifier(max_features='sqrt', random_state=872671433),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1124972918),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1585356263),
#  DecisionTreeClassifier(max_features='sqrt', random_state=131448440),
#  DecisionTreeClassifier(max_features='sqrt', random_state=444537088),
#  DecisionTreeClassifier(max_features='sqrt', random_state=354616319),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1367867462),
#  DecisionTreeClassifier(max_features='sqrt', random_state=108137272),
#  DecisionTreeClassifier(max_features='sqrt', random_state=397762448),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1777283950),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1885879869),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1647751767),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1957985434),
#  DecisionTreeClassifier(max_features='sqrt', random_state=823346653),
#  DecisionTreeClassifier(max_features='sqrt', random_state=607029625),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1361998051),
#  DecisionTreeClassifier(max_features='sqrt', random_state=628310650),
#  DecisionTreeClassifier(max_features='sqrt', random_state=277927730),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1117087296),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2079366990),
#  DecisionTreeClassifier(max_features='sqrt', random_state=505128251),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1771133173),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1385819219),
#  DecisionTreeClassifier(max_features='sqrt', random_state=47740458),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1259744714),
#  DecisionTreeClassifier(max_features='sqrt', random_state=906599262),
#  DecisionTreeClassifier(max_features='sqrt', random_state=923037776),
#  DecisionTreeClassifier(max_features='sqrt', random_state=132932102),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1682550664),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1051102146),
#  DecisionTreeClassifier(max_features='sqrt', random_state=571439614),
#  DecisionTreeClassifier(max_features='sqrt', random_state=766114173),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1154145491),
#  DecisionTreeClassifier(max_features='sqrt', random_state=64514806),
#  DecisionTreeClassifier(max_features='sqrt', random_state=719142643),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1724082991),
#  DecisionTreeClassifier(max_features='sqrt', random_state=688691565),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1305976903),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1233563762),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1916724708),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1492412680),
#  DecisionTreeClassifier(max_features='sqrt', random_state=485052272),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1790309020),
#  DecisionTreeClassifier(max_features='sqrt', random_state=208267618),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1019524731),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1826569175),
#  DecisionTreeClassifier(max_features='sqrt', random_state=659479458),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1729770152),
#  DecisionTreeClassifier(max_features='sqrt', random_state=307630384),
#  DecisionTreeClassifier(max_features='sqrt', random_state=926631078),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1760047424),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1292020141),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1678813346),
#  DecisionTreeClassifier(max_features='sqrt', random_state=153134655),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1284054184),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1088198856),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1843513491)]
