# %%
pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=31faa8a40ab8b4fcecb14ed080c0d968605ac13a4901b2c6f4425b03f56cb37d
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
url="https://www.fabhotels.com/blog/festivals-of-india/"

# %%
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/> <link href="https://www.fabhotels.com/blog/xmlrpc.php" rel="pingback"/> <link href="https://static.fabhotels.com/img/icons/android-icon-192x192_v1.png" rel="icon" sizes="192x192" type="image/png"/> <link href="https://static.fabhotels.com/img/icons/favicon-32x32_v1.png" rel="icon" sizes="32x32" type="image/png"/> <link href="https://static.fabhotels.com/img/icons/favicon-96x96_v1.png" rel="icon" sizes="96x96" type="image/png"/> <link href="https://static.fabhotels.com/img/icons/favicon-16x16_v1.png" rel="icon" sizes="16x16" type="image/png"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
# <!-- This site is optimized with the Yoast SEO plugin v21.7 - https://yoast.com/wordpress/plugins/seo/ -->
# ...

# %%
title = soup.find('title')
print(title)
# Out:
# <title>24 National Festivals of India, Religious Festivals Blogs</title>

# %%
print(title.text)
# Out:
# 24 National Festivals of India, Religious Festivals Blogs

# %%
table = soup.find('table')
print(table)
# Out:
# <table border="1" width="100%">
# <thead>
# <tr>
# <th width="20%"><strong>Festivals in India</strong></th>
# <th width="20%"><strong>Day</strong></th>
# <th width="20%"><strong>Date</strong></th>
# <th width="20%"><strong>Holiday Type</strong></th>
# <th width="20%"><strong>Festival Type</strong></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><a href="https://www.fabhotels.com/blog/indian-holiday-calendar/new-year/">New Year</a></td>
# <td>Sunday</td>
# <td>1-Jan-2023</td>
# <td>Public</td>
# <td>Religious</td>
# </tr>
# <tr>
# <td><a href="https://www.fabhotels.com/blog/indian-holiday-calendar/makar-sankranti/">Makar Sankranti</a></td>
# <td>Saturday</td>
# <td>14-Jan-2023</td>
# <td>Restricted</td>
# <td>Religious</td>
# </tr>
# <tr>
# <td><a href="https://www.fabhotels.com/blog/indian-holiday-calendar/lohri/">Lohri</a></td>
# <td>Saturday</td>
# <td>14-Jan-2023</td>
# <td>Restricted</td>
# <td>Religious</td>
# </tr>
# <tr>
# ...

# %%
Headings = table.find_all('th')
print(Headings)
# Out:
# [<th width="20%"><strong>Festivals in India</strong></th>, <th width="20%"><strong>Day</strong></th>, <th width="20%"><strong>Date</strong></th>, <th width="20%"><strong>Holiday Type</strong></th>, <th width="20%"><strong>Festival Type</strong></th>]

# %%
Header = [i.text for i in Headings]
print(Header)
# Out:
# ['Festivals in India', 'Day', 'Date', 'Holiday Type', 'Festival Type']

# %%
import pandas as pd
df = pd.DataFrame(columns = Header)
df
# Out:
# Empty DataFrame
# Columns: [Festivals in India, Day, Date, Holiday Type, Festival Type]
# Index: []

# %%
rows = table.find_all('tr')
print(rows)
print(df.columns)
# Out:
# [<tr>
# <th width="20%"><strong>Festivals in India</strong></th>
# <th width="20%"><strong>Day</strong></th>
# <th width="20%"><strong>Date</strong></th>
# <th width="20%"><strong>Holiday Type</strong></th>
# <th width="20%"><strong>Festival Type</strong></th>
# </tr>, <tr>
# <td><a href="https://www.fabhotels.com/blog/indian-holiday-calendar/new-year/">New Year</a></td>
# <td>Sunday</td>
# <td>1-Jan-2023</td>
# <td>Public</td>
# <td>Religious</td>
# </tr>, <tr>
# <td><a href="https://www.fabhotels.com/blog/indian-holiday-calendar/makar-sankranti/">Makar Sankranti</a></td>
# <td>Saturday</td>
# <td>14-Jan-2023</td>
# <td>Restricted</td>
# <td>Religious</td>
# </tr>, <tr>
# <td><a href="https://www.fabhotels.com/blog/indian-holiday-calendar/lohri/">Lohri</a></td>
# <td>Saturday</td>
# <td>14-Jan-2023</td>
# <td>Restricted</td>
# <td>Religious</td>
# </tr>, <tr>
# <td><a href="https://www.fabhotels.com/blog/indian-holiday-calendar/pongal/">Pongal</a></td>
# <td>Sunday</td>
# ...

# %%
ind=1
for i in rows[1:25]:
  row_data = i.find_all('td')
  every_row_data = [i.text for i in row_data]
  print(every_row_data)
  df.loc[ind] = every_row_data
  ind = ind+1
# Out:
# ['New Year', 'Sunday', '1-Jan-2023', 'Public', 'Religious']
# ['Makar Sankranti', 'Saturday', '14-Jan-2023', 'Restricted', 'Religious']
# ['Lohri', 'Saturday', '14-Jan-2023', 'Restricted', 'Religious']
# ['Pongal', 'Sunday', '15-Jan-2023', 'Restricted', 'Religious']
# ['Basant Panchmi', 'Thursday', '26-Jan-2023', 'Restricted', 'Religious']
# ['Republic Day', 'Thursday', '26-Jan-2023', 'Public', 'National']
# ['Guru Ravidass Jayanti', 'Sunday', '5-Feb-2023', 'Restricted', 'Religious']
# ['Lui-Ngai-Ni', 'Wednesday', '15-Feb-2023', 'Restricted', 'Religious']
# ['Maharishi Dayanand Saraswati Jayanti', 'Wednesday', '15-Feb-2023', 'Restricted', 'Religious']
# ['Mahashivratri', 'Saturday', '18-Feb-2023', 'Restricted', 'Religious']
# ['Losar', 'Tuesday', '21-Feb-2023', 'Restricted', 'Religious']
# ['Gangaur', 'Wednesday', '1-Mar-2023', 'Restricted', 'Religious']
# ['Holi', 'Wednesday', '8-Mar-2023', 'Public', 'Religious']
# ['Ugadi', 'Wednesday', '22-Mar-2023', 'Restricted', 'Religious']
# ...

# %%
df
df.to_csv("list of indian festivals.csv")
